# %% [markdown]
# ## PHSX 815 Neural Network with Keras tutorial
# ### How can we predict the quality of wine based on its physical characteristics?
# We will download the `wine_quality` dataset from Tensorflow (the Keras backend) to train a neural network to predict wine quality.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
# from tensorflow.keras.optimizers import SGD, Adam
# from tensorflow.keras.activations import relu
import tensorflow_datasets as tfds
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#if you want to load the data as tuples, you can use the as_supervised=True argument
data_train = tfds.load('wine_quality',split='train',as_supervised=True)

#looking at just one sample of our data
pt = data_train.take(1)

#type(pt)

#can convert this TakeDataset object to a numpy array (can do this for the whole dataset too)
print("Features and label for first entry")
for features, label in tfds.as_numpy(pt):
    print(features, label)

#we want to load dataset as a a dictionary of tf.Tensors (can't transform tuples to dataframe)
data_train_white = tfds.load('wine_quality/white',split='train')
data_train_red = tfds.load('wine_quality/red',split='train')

#transform dictionary to dataframe - combining red and white wine
df_white = tfds.as_dataframe(data_train_white)
df_red = tfds.as_dataframe(data_train_red)
df = pd.concat([df_white,df_red])

print('number of samples',len(df['quality']))

#what are our output possibilities?
print('possible wine quality ratings',df['quality'].unique())
# Out:
# Features and label for first entry
# {'alcohol': 9.0, 'chlorides': 0.054, 'citric acid': 0.34, 'density': 1.0008, 'fixed acidity': 7.6, 'free sulfur dioxide': 44.0, 'pH': 3.22, 'residual sugar': 18.35, 'sulphates': 0.550000011920929, 'total sulfur dioxide': 197.0, 'volatile acidity': 0.32} 5
# number of samples 6497
# possible wine quality ratings [5 6 4 8 7 3 9]

# %%
#do we have any missing data (empty or NaN entries in features or labels)?
dataNans = df.isnull().values.any()
if not dataNans:
    print("all good!")
# Out:
# all good!

# %% [markdown]
# ### Preprocessing our labels
# Although this may seem like a regression task for a neural network because we are predicting a number (wine quality), the labels are actually *categorical* not *continuous*. If you look at the labels, you see that they are integer values between 5 and 9. Because this is a classification problem, we need to one-hot encode our labels. This means taking our possible outcomes and turning them into arrays of a 1 and 0's. The index of the 1 in the array will tell us which class is which. So, for example, 5 becomes [1,0,0,0,0], 6 becomes [0,1,0,0,0] and so on. We can use a function from sklearn to do this automatically.

# %% [markdown]
# this dataset unfortunately only gives us training data - but we can set aside a portion for testing our network on. in practice, you don't want to test your network on data it has already seen (is it really a prediction if you use your model on data it was fitted to?) but, for educational purposes, we can ~randomly sample our data and call it ~iid.
# Here, I combine the red and white wine datasets for increased statistics. What happens if you train networks on these datasets separately? Or what happens if you use one dataset to train and one to test?

# %%
#it's helpful to separate our input features from our target features (quality) 
#so we can later only transform our inputs without changing our labels
labels = df['quality']
df = df.drop(labels='quality',axis=1)
labels.unique()

enc = OneHotEncoder(sparse=False)
labels = enc.fit_transform(labels.to_numpy().reshape(-1,1))

#make our test data
df, df_test, labels, df_testLabels = train_test_split(df,labels,test_size=0.1)

#look at the first 5 entries
df.head()

#do we have any missing data (empty or NaN entries in features or labels)?
dataNans = df.isnull().values.any()
if not dataNans:
    print("all good again!")
    
pl = sns.pairplot(df[df.columns], diag_kind='kde')
# Out:
# array([5, 6, 4, 8, 7, 3, 9])
#       features/alcohol  features/chlorides  features/citric acid  \
# 662               9.00               0.070                  0.58
# 2454             10.15               0.030                  0.22
# 2075              9.90               0.058                  0.38
# 1257              9.80               0.048                  0.22
# 3196              9.30               0.052                  0.36
#
#       features/density  features/fixed acidity  features/free sulfur dioxide  \
# 662            1.00040                    13.3                          15.0
# 2454           0.99218                     5.2                          47.0
# 2075           0.99400                     7.8                          14.0
# 1257           0.99304                     6.3                          53.0
# 3196           0.99840                     6.5                          53.0
#
#       features/pH  features/residual sugar  features/sulphates  \
# 662          3.06                      1.9                0.49
# 2454         3.55                      1.0                0.44
# 2075         3.21                      2.1                0.55
# 1257         3.24                      2.8                0.45
# 3196         3.44                     11.0                0.55
#
#       features/total sulfur dioxide  features/volatile acidity
# 662                            40.0                      0.430
# 2454                          123.0                      0.185
# 2075                          167.0                      0.240
# 1257                          173.0                      0.390
# 3196                          247.0                      0.340
# all good again!

# %% [markdown]
# ### some questions to consider:
# - how was this data obtained? what goes into engineering the features? what does "quality" mean? \
# <span style="color:blue;" >Ans: The data was obtained by taking 90% of data from the original dataframe </span> `df`<span style="color:blue;" > by using the function </span> `train_test_split`<span style="color:blue;" >. The rest 10% is stored in </span> `df_test`.
# <span style="color:blue;" > The "quality" means the wine quality which we call here labels. The  `OneHotEncoder` <span style="color:blue;" >  function encodes the labels as 0 and 1 arrays    . </span>
# - do you have to normalize your features? \
# <span style="color:blue;" >Ans: Features are not normalized to unit (there are entries greater than 1). We could do this with the function) </span> `normalize`.
# - are there any correlations among features? is this expected? how can we encode this information to the NN or decouple these features? \
# <span style="color:blue;" >Ans: Yes, there are correlations between different features (e.g. pH, fixed acidity and volatile acidity) </span>
# - what does the data look like? \
# <span style="color:blue;" >Ans: The figure above. </span>
# - do we have any missing or NaN entries? \
# <span style="color:blue;" >Ans: No. </span>

# %% [markdown]
# let's examine the data to see what kinds of transformations we need to make for preprocessing

# %%
df.describe()
# Out:
#        features/alcohol  features/chlorides  features/citric acid  \
# count       5847.000000         5847.000000           5847.000000
# mean          10.488080            0.056005              0.319714
# std            1.191265            0.034614              0.145166
# min            8.000000            0.009000              0.000000
# 25%            9.500000            0.038000              0.250000
# 50%           10.300000            0.047000              0.310000
# 75%           11.300000            0.065000              0.395000
# max           14.900000            0.611000              1.660000
#
#        features/density  features/fixed acidity  features/free sulfur dioxide  \
# count       5847.000000             5847.000000                   5847.000000
# mean           0.994716                7.228690                     30.583633
# std            0.003008                1.305695                     17.876925
# min            0.987110                3.800000                      1.000000
# 25%            0.992340                6.400000                     17.000000
# 50%            0.994900                7.000000                     29.000000
# 75%            0.997000                7.700000                     41.000000
# max            1.038980               15.900000                    289.000000
#
#        features/pH  features/residual sugar  features/sulphates  \
# count  5847.000000              5847.000000         5847.000000
# mean      3.217597                 5.449239            0.531435
# std       0.159859                 4.778039            0.149671
# min       2.720000                 0.600000            0.220000
# 25%       3.110000                 1.800000            0.430000
# 50%       3.210000                 3.000000            0.510000
# 75%       3.320000                 8.100000            0.600000
# max       4.010000                65.800003            2.000000
#
#        features/total sulfur dioxide  features/volatile acidity
# count                    5847.000000                5847.000000
# mean                      115.551308                   0.339693
# std                        56.355539                   0.165526
# min                         6.000000                   0.080000
# 25%                        77.000000                   0.230000
# 50%                       118.000000                   0.290000
# 75%                       156.000000                   0.402500
# max                       440.000000                   1.580000

# %% [markdown]
# ### Visualizing data
# If you want a cool and easy way to visualize not only the features, but also the correlations between features, you can use the following seaborn function, which will display the individual features on the diagonal of the subplots and the correlations between features
#
# `pl = sns.pairplot(df[df.columns], diag_kind='kde')`

# %%
#visualizing our input features
nFeatures = len(df.columns)
nCols = 3
nRows = int(np.ceil(nFeatures/nCols))
cols = df.columns
fig, axs = plt.subplots(nRows,nCols,figsize=(15,20))
# for i, ax in enumerate(axs)
col = 0
for i in range(nRows):
    for j in range(nCols):
        if col >= nFeatures:
            break
        h = axs[i,j].hist(df[cols[col]])
        h = axs[i,j].set_title(cols[col])
        col += 1

# %% [markdown]
# It looks like there are two types of sulfur dioxide features: total sulfur dioxide and free sulfur dioxide. I'm not entirely sure what sulfur dioxide is (I am neither a chemist nor a sommelier) so I'm curious if there is a correlation between these features.

# %%
plt.scatter(df['features/free sulfur dioxide'],df['features/total sulfur dioxide'])

# %% [markdown]
# It looks like there is some correlation between these features. If I had to guess, I would say "free sulfur dioxide" is a subset of "total sulfur dioxide" but I'm not sure how or even if either of these features would affect the wine quality. This is where domain specific knowledge would be helpful! Since I have a degree in physics and not wine studies (contrary to what my weekend activities may imply) I am going to see what happens when we include both of these features in our network.

# %% [markdown]
# This was just a cursory look at our data. In reality, data scientists will spend most of their time feature engineering, fixing incomplete datasets, cleaning data, etc. Feel free to do more exploratory analysis on the data before you pass it through to a network!

# %% [markdown]
# ## Let's build our network!
# We want to build a simple DNN to essentially perform a categorization. Let's start with something simple: only a couple hidden layers and a handful of neurons. Of course, in accordance with the Universal Approximation Theorem, any function can be approximated arbitrarily well with an arbitrarily large number of layers (Lu et. al. 2017) or arbitrarily large number of neurons (Cybenko 1989). Does the network perform better or worse with an increase in layers or neurons?

# %%
cols = df.columns
nClasses = len(labels[0])

#using Keras's Sequential model - https://keras.io/api/models/sequential/
model = Sequential()
#add input layer
model.add(Input(shape=(len(cols),))) #the input layer shape should match the number of features we have
#add first layer of fully connected neurons
model.add(Dense(64,activation='relu'))
#add second layer (first hidden layer)
model.add(Dense(64,activation='relu'))
#and one more because why not
model.add(Dense(64,activation='relu'))
#finally, our output layer should have only one neuron because we are trying to predict only one number
#notice how there is a different activation function in this layer
#this is because we want our outputs for each class to be a probability
model.add(Dense(nClasses,activation='softmax'))

#compile our model - set our loss metric (categorical cross entropy) and optimizer (stochastic gradient descent)
#how does the model performance change with different optimizers (ie AdaGrad, SGD, etc.)?
model.compile(loss='CategoricalCrossentropy',optimizer='Adam',metrics=['accuracy'])

#let's see a summary of our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                768
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 9,543
# Trainable params: 9,543
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# As shown above, we have a network with four layers, 128 neurons/layer, for a total of ~50k trainable parameters (remember: parameters are the biases and weights that the network learns). Imagine how many parameters a large, complex network at Google has!

# %% [markdown]
# ### the same model can be built using the generic Model class and slightly different syntax
# `
# inputs = tf.keras.Input(shape=(len(cols),))
# outputs_L1 = Dense(64, activation='relu')(inputs)
# outputs_L2 = Dense(64, activation='relu')(outputs_L1)
# outputs_L3 = Dense(64, activation='relu')(outputs_L2)
# pred = Dense(1)(outputs_L3)
# model = Model(inputs=inputs,outputs=pred)
# `

# %% [markdown]
# ### Training our model
#
# Let's give our model all the input features (df), the corresponding labels (labels)
#
# There is a 20% validation split, which means that 80% of our data will be used to train the model parameters
# while 20% of it will be saved to "check" our answers. This is data that the model has not seen (been trained on) so the performance on the validation data should give us an idea of if the model is over- or underfitting.
#
# We will train for 100 epochs, which means that the entire dataset will be passed through the whole network 100 times. Our batch size is 20, meaning that 20 samples at a time are passed to the network before the parameters are updated. The `shuffle` argument ensures that our data is shuffled before the beginning of each epoch to reduce spurious learned correlations. What happens if you let the model run for more epochs?

# %%
history = model.fit(
    df, labels,
    validation_split=0.3,
    verbose=1, epochs=100, batch_size=100, shuffle=True)
# Out:
# Epoch 1/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8216 - accuracy: 0.6425 - val_loss: 0.9465 - val_accuracy: 0.6074
# Epoch 2/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8260 - accuracy: 0.6334 - val_loss: 0.9651 - val_accuracy: 0.6063
# Epoch 3/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8257 - accuracy: 0.6359 - val_loss: 0.9516 - val_accuracy: 0.6097
# Epoch 4/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8168 - accuracy: 0.6461 - val_loss: 0.9692 - val_accuracy: 0.6011
# Epoch 5/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8255 - accuracy: 0.6383 - val_loss: 0.9687 - val_accuracy: 0.5977
# Epoch 6/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8182 - accuracy: 0.6435 - val_loss: 0.9662 - val_accuracy: 0.6028
# Epoch 7/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8083 - accuracy: 0.6415 - val_loss: 0.9805 - val_accuracy: 0.6006
# Epoch 8/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8124 - accuracy: 0.6496 - val_loss: 0.9844 - val_accuracy: 0.5926
# Epoch 9/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8035 - accuracy: 0.6471 - val_loss: 0.9789 - val_accuracy: 0.6080
# Epoch 10/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7992 - accuracy: 0.6535 - val_loss: 1.0100 - val_accuracy: 0.5880
# Epoch 11/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8141 - accuracy: 0.6369 - val_loss: 0.9654 - val_accuracy: 0.5972
# Epoch 12/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7986 - accuracy: 0.6527 - val_loss: 0.9766 - val_accuracy: 0.6097
# Epoch 13/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8055 - accuracy: 0.6503 - val_loss: 0.9927 - val_accuracy: 0.5897
# Epoch 14/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8030 - accuracy: 0.6496 - val_loss: 0.9870 - val_accuracy: 0.5932
# Epoch 15/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8049 - accuracy: 0.6498 - val_loss: 1.0006 - val_accuracy: 0.6023
# Epoch 16/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8038 - accuracy: 0.6474 - val_loss: 0.9938 - val_accuracy: 0.6011
# Epoch 17/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8127 - accuracy: 0.6344 - val_loss: 0.9767 - val_accuracy: 0.6017
# Epoch 18/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8055 - accuracy: 0.6476 - val_loss: 1.0241 - val_accuracy: 0.5915
# Epoch 19/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8131 - accuracy: 0.6444 - val_loss: 0.9825 - val_accuracy: 0.5932
# Epoch 20/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8075 - accuracy: 0.6481 - val_loss: 0.9946 - val_accuracy: 0.5954
# Epoch 21/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8061 - accuracy: 0.6508 - val_loss: 1.0118 - val_accuracy: 0.5892
# Epoch 22/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8013 - accuracy: 0.6508 - val_loss: 1.0334 - val_accuracy: 0.5829
# Epoch 23/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8133 - accuracy: 0.6444 - val_loss: 0.9830 - val_accuracy: 0.5966
# Epoch 24/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8108 - accuracy: 0.6437 - val_loss: 1.0002 - val_accuracy: 0.5932
# Epoch 25/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7965 - accuracy: 0.6520 - val_loss: 1.0065 - val_accuracy: 0.5852
# Epoch 26/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8038 - accuracy: 0.6447 - val_loss: 1.0110 - val_accuracy: 0.5823
# Epoch 27/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8144 - accuracy: 0.6391 - val_loss: 1.0387 - val_accuracy: 0.5755
# Epoch 28/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7943 - accuracy: 0.6549 - val_loss: 1.0116 - val_accuracy: 0.5886
# Epoch 29/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8049 - accuracy: 0.6503 - val_loss: 1.0264 - val_accuracy: 0.5835
# Epoch 30/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8027 - accuracy: 0.6508 - val_loss: 0.9995 - val_accuracy: 0.5989
# Epoch 31/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7887 - accuracy: 0.6471 - val_loss: 0.9927 - val_accuracy: 0.6040
# Epoch 32/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8002 - accuracy: 0.6508 - val_loss: 1.0267 - val_accuracy: 0.5829
# Epoch 33/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7925 - accuracy: 0.6559 - val_loss: 1.0474 - val_accuracy: 0.5744
# Epoch 34/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7949 - accuracy: 0.6515 - val_loss: 1.0110 - val_accuracy: 0.5823
# Epoch 35/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8080 - accuracy: 0.6388 - val_loss: 1.0172 - val_accuracy: 0.5880
# Epoch 36/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7896 - accuracy: 0.6532 - val_loss: 1.0258 - val_accuracy: 0.5818
# Epoch 37/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7935 - accuracy: 0.6476 - val_loss: 1.0401 - val_accuracy: 0.5926
# Epoch 38/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7859 - accuracy: 0.6515 - val_loss: 1.0377 - val_accuracy: 0.5783
# Epoch 39/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8039 - accuracy: 0.6496 - val_loss: 1.0338 - val_accuracy: 0.5875
# Epoch 40/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.8015 - accuracy: 0.6530 - val_loss: 1.0181 - val_accuracy: 0.5863
# Epoch 41/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7847 - accuracy: 0.6449 - val_loss: 1.0153 - val_accuracy: 0.5966
# Epoch 42/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7850 - accuracy: 0.6554 - val_loss: 1.0289 - val_accuracy: 0.5903
# Epoch 43/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7903 - accuracy: 0.6576 - val_loss: 1.0154 - val_accuracy: 0.5835
# Epoch 44/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7902 - accuracy: 0.6522 - val_loss: 1.0189 - val_accuracy: 0.5909
# Epoch 45/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.7790 - accuracy: 0.6554 - val_loss: 1.0400 - val_accuracy: 0.5897
# Epoch 46/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7883 - accuracy: 0.6549 - val_loss: 1.0301 - val_accuracy: 0.5863
# Epoch 47/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7884 - accuracy: 0.6527 - val_loss: 1.0412 - val_accuracy: 0.5886
# Epoch 48/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7798 - accuracy: 0.6513 - val_loss: 1.0259 - val_accuracy: 0.5823
# Epoch 49/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7876 - accuracy: 0.6491 - val_loss: 1.0153 - val_accuracy: 0.5852
# Epoch 50/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7742 - accuracy: 0.6601 - val_loss: 1.0159 - val_accuracy: 0.5926
# Epoch 51/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7710 - accuracy: 0.6613 - val_loss: 1.0383 - val_accuracy: 0.5812
# Epoch 52/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7878 - accuracy: 0.6452 - val_loss: 1.0644 - val_accuracy: 0.5829
# Epoch 53/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7837 - accuracy: 0.6510 - val_loss: 1.0387 - val_accuracy: 0.5772
# Epoch 54/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7860 - accuracy: 0.6505 - val_loss: 1.0523 - val_accuracy: 0.5812
# Epoch 55/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7862 - accuracy: 0.6601 - val_loss: 1.0354 - val_accuracy: 0.5778
# Epoch 56/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7897 - accuracy: 0.6520 - val_loss: 1.0366 - val_accuracy: 0.5920
# Epoch 57/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7744 - accuracy: 0.6552 - val_loss: 1.0389 - val_accuracy: 0.5863
# Epoch 58/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7772 - accuracy: 0.6598 - val_loss: 1.0716 - val_accuracy: 0.5772
# Epoch 59/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7746 - accuracy: 0.6593 - val_loss: 1.0425 - val_accuracy: 0.5892
# Epoch 60/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7695 - accuracy: 0.6645 - val_loss: 1.0463 - val_accuracy: 0.5863
# Epoch 61/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7776 - accuracy: 0.6554 - val_loss: 1.0752 - val_accuracy: 0.5635
# Epoch 62/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7968 - accuracy: 0.6466 - val_loss: 1.0451 - val_accuracy: 0.5789
# Epoch 63/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7763 - accuracy: 0.6659 - val_loss: 1.0721 - val_accuracy: 0.5812
# Epoch 64/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7702 - accuracy: 0.6659 - val_loss: 1.0743 - val_accuracy: 0.5869
# Epoch 65/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7887 - accuracy: 0.6552 - val_loss: 1.0433 - val_accuracy: 0.5709
# Epoch 66/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7807 - accuracy: 0.6569 - val_loss: 1.0729 - val_accuracy: 0.5749
# Epoch 67/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7755 - accuracy: 0.6615 - val_loss: 1.0581 - val_accuracy: 0.5840
# Epoch 68/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7737 - accuracy: 0.6640 - val_loss: 1.0603 - val_accuracy: 0.5789
# Epoch 69/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7751 - accuracy: 0.6615 - val_loss: 1.0598 - val_accuracy: 0.5761
# Epoch 70/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7649 - accuracy: 0.6650 - val_loss: 1.0674 - val_accuracy: 0.5607
# Epoch 71/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7763 - accuracy: 0.6657 - val_loss: 1.0773 - val_accuracy: 0.5869
# Epoch 72/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7732 - accuracy: 0.6610 - val_loss: 1.0446 - val_accuracy: 0.5932
# Epoch 73/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7673 - accuracy: 0.6689 - val_loss: 1.0474 - val_accuracy: 0.5869
# Epoch 74/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7676 - accuracy: 0.6596 - val_loss: 1.0662 - val_accuracy: 0.5801
# Epoch 75/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7612 - accuracy: 0.6738 - val_loss: 1.0698 - val_accuracy: 0.5715
# Epoch 76/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7533 - accuracy: 0.6696 - val_loss: 1.0527 - val_accuracy: 0.5937
# Epoch 77/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7539 - accuracy: 0.6662 - val_loss: 1.0708 - val_accuracy: 0.5766
# Epoch 78/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7695 - accuracy: 0.6647 - val_loss: 1.0624 - val_accuracy: 0.5920
# Epoch 79/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7665 - accuracy: 0.6674 - val_loss: 1.0827 - val_accuracy: 0.5738
# Epoch 80/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7654 - accuracy: 0.6628 - val_loss: 1.0753 - val_accuracy: 0.5869
# Epoch 81/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7750 - accuracy: 0.6613 - val_loss: 1.0730 - val_accuracy: 0.5886
# Epoch 82/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.7617 - accuracy: 0.6711 - val_loss: 1.0813 - val_accuracy: 0.5715
# Epoch 83/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7564 - accuracy: 0.6733 - val_loss: 1.0809 - val_accuracy: 0.5880
# Epoch 84/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7583 - accuracy: 0.6706 - val_loss: 1.0813 - val_accuracy: 0.5715
# Epoch 85/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7576 - accuracy: 0.6701 - val_loss: 1.0602 - val_accuracy: 0.5897
# Epoch 86/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.7545 - accuracy: 0.6664 - val_loss: 1.0775 - val_accuracy: 0.5789
# Epoch 87/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.7602 - accuracy: 0.6720 - val_loss: 1.0870 - val_accuracy: 0.5766
# Epoch 88/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.7599 - accuracy: 0.6689 - val_loss: 1.1149 - val_accuracy: 0.5641
# Epoch 89/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7661 - accuracy: 0.6640 - val_loss: 1.0969 - val_accuracy: 0.5675
# Epoch 90/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7886 - accuracy: 0.6593 - val_loss: 1.0741 - val_accuracy: 0.5795
# Epoch 91/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7709 - accuracy: 0.6618 - val_loss: 1.1199 - val_accuracy: 0.5692
# Epoch 92/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7683 - accuracy: 0.6657 - val_loss: 1.0885 - val_accuracy: 0.5721
# Epoch 93/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7580 - accuracy: 0.6718 - val_loss: 1.0901 - val_accuracy: 0.5761
# Epoch 94/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7479 - accuracy: 0.6755 - val_loss: 1.0995 - val_accuracy: 0.5789
# Epoch 95/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7574 - accuracy: 0.6667 - val_loss: 1.1017 - val_accuracy: 0.5709
# Epoch 96/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7487 - accuracy: 0.6747 - val_loss: 1.0841 - val_accuracy: 0.5840
# Epoch 97/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7512 - accuracy: 0.6718 - val_loss: 1.1038 - val_accuracy: 0.5795
# Epoch 98/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7449 - accuracy: 0.6752 - val_loss: 1.1000 - val_accuracy: 0.5829
# Epoch 99/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7472 - accuracy: 0.6745 - val_loss: 1.1112 - val_accuracy: 0.5664
# Epoch 100/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7491 - accuracy: 0.6833 - val_loss: 1.1056 - val_accuracy: 0.5806

# %% [markdown]
# Let's define a function to visualize our loss

# %%
def show_loss(history):
    plt.figure()
    plt.plot(history.history['val_loss'], label="val loss")
    plt.plot(history.history['loss'],label="train loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
show_loss(history)

# %% [markdown]
# It looks like our training loss is more or less monotonically minimized with each epoch (with some fluctuations) while the validation loss seems to be on average higher. The validation loss spikes more severely than the training loss, which is probably due to limited statistics (we only had ~6k samples and took onlt 20% of them for validation - it usually takes LOTS of data to train neural networks well!). The trend discrepancy between training and validation losses could indicate some overfitting in our model. What happens if you increase the percentage of data used for validation? Since it's pretty apparent we're overfitting to our training data, we could introduce some sort of regularization techniques, like L2 regularization (that penalizes large weights) or dropout (that randomly drops neurons in a layer with a set probability). What happens if you introduce some of these methods?

# %% [markdown]
# ### Remember that test data we set aside at the beginning?
# Now it's time to use it to evaluate our model performance!

# %%
_, acc = model.evaluate(df_test, df_testLabels, verbose=1)
print('Accuracy for test data is',acc)
# Out:
# 21/21 [==============================] - 0s 1ms/step - loss: 1.3569 - accuracy: 0.5077
# Accuracy for test data is 0.5076923370361328

# %% [markdown]
# To plot our results, I just chose the highest probability of the classes and assigned the prediction to a class based on that rounding (highest probability gets a 1, every other class gets a 0). Then, I one-hot decoded the rounded array to get a single number for the class.

# %%
preds = model.predict(df_test)
#preds = [i.round() for i in preds]
preds = tf.one_hot(tf.math.argmax(preds, axis = 1), depth = len(preds[0]))
preds = enc.inverse_transform(preds)
testLabels = enc.inverse_transform(df_testLabels)
cm = confusion_matrix(testLabels, preds)
     
_ =plt.imshow(cm, cmap=plt.cm.Blues)
_ = plt.xlabel("Predicted labels")
_ = plt.ylabel("True labels")

_ =plt.xticks(np.arange(0,len(np.unique(testLabels)),1),np.unique(testLabels))
_ =plt.yticks(np.arange(0,len(np.unique(testLabels)),1),np.unique(testLabels))
_ =plt.title('Confusion matrix ')
_ =plt.colorbar()
plt.show()

# %% [markdown]
# It looks like our network is only predicting *some* of our classes. Maybe that's because really good wine (rated 8 and 9) is pretty rare? Let's check it out.

# %%
_=plt.hist(enc.inverse_transform(labels),label='training labels')
_=plt.hist(testLabels,label='test labels')
_=plt.yscale('log')
_=plt.legend()

# %% [markdown]
# Yep! Mostly 5s, 6s, and 7s. Only a handful of really good wines (8s and 9s) and really bad wines (3s and 4s). In fact, no scores below a 3! But no perfect 10s either. Overall, I would say that the dataset is imbalanced (mostly ok wines, some bad and some good - a pretty Gaussian distribution) and could benefit from data augmentation techniques like bootstrapping! Maybe you could even generate some more data from randomly sampling a known distribution...But if you train your model on mostly ok wines, then it learns the characteristics of those wines really well. So, when it's faced with a good or bad wine, it's not as sure how to classify it. You can see if this is happening by looking at the network output, which are the probabilities for each class (ie how sure the network is this sample belongs to a certain class).

# %% [markdown]
# ### Overall,
# our network performs ok with a training, validation, and test accuracy all around 50-60%. What could you change about the network or inputs? How do you think that would affect the model's predictions?
